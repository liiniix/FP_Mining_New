# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'FP': [28.05, 9.236, 7.60, 2.87, 0.664], 'Apriori': [152.72, 87.86,  60.34, 29.44, 13.20]}, index=[83, 85, 87, 89, 91])
lines = df.plot.line(title="Chess (Time)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("time (sec)")
plt.savefig('/home/os/github/FP_Mining/time/chess_time.png')

# %%
df = pd.DataFrame({'FP': [14940.0, 14880.0, 14776.0, 14668.0, 14608.0], 
                   'Apriori': [17808.0, 17172.0,  16492.0, 16080.0, 15808.0]}, 
                  index=[83, 85, 87, 89, 91])
lines = df.plot.line(title="Chess (Mem)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("Mem (KB)")
plt.savefig('/home/os/github/FP_Mining/mem/chess_time.png')

# %%
df = pd.DataFrame({'FP': [140.86, 94.92, 112.32, 46.20, 4.22, 2.30], 'Apriori': [124.15, 114.0, 86.11, 42.72, 20.50, 12.61]},
                  index=[28, 29, 30, 35, 40, 42])
lines = df.plot.line(title="Mushroom (Time)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("time (sec)")
plt.savefig('/home/os/github/FP_Mining/time/mushroom_time.png')

# %%
df = pd.DataFrame({'FP': [16556.0 , 16028.0, 15848.0, 15736.0, 15764.0], 
                   'Apriori': [18524.0, 17528.0, 17348.0, 16840.0, 16772.0]},
                  index=[28, 32, 36, 40, 44])
lines = df.plot.line(title="Mushroom (Mem)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("Mem (KB)")
plt.savefig('/home/os/github/FP_Mining/mem/mushroom_time.png')

# %%
df = pd.DataFrame({'Apriori': [127.20, 81.58, 68.66, 46.82], 'FP': [19.02, 4.009, 2.627, 2.681]},
                  index=[56, 60, 62, 64])
lines = df.plot.line(title="Pumsb_star (Time)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("time (sec)")
plt.savefig('/home/os/github/FP_Mining/time/pumsb_star_time.png')

# %%
df = pd.DataFrame({'Apriori': [189116.0, 189324.0, 189308.0, 188948.0, 46.20, 4.22, 2.30], 
                   'FP': [189364.0 ,188768.0, 188552.0, 86.11, 42.72, 20.50, 12.61]},
                  index=[56, 60, 62, 64, 35, 40, 42])
lines = df.plot.line(title="Pumsb_star (Mem)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("Mem (KB)")
plt.savefig('/home/os/github/FP_Mining/mem/pumsb_star_time.png')

# %%
df = pd.DataFrame({'Apriori': [5.91, 3.63, 1.97, 1.80, 1.621], 'FP': [3.32, 1.27, 0.86, 0.833, 0.818]},
                  index=[2, 3, 4, 5, 7])
lines = df.plot.line(title="Retail (Time)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("time (sec)")
plt.savefig('/home/os/github/FP_Mining/time/retail_time.png')

# %%
df = pd.DataFrame({'Apriori': [84948.0, 84976.0 , 85040.0, 84808.0, 85132.0], 
                   'FP': [85072.0 ,84184.0, 84200.0, 84104.0, 84180.0]},
                  index=[2, 3, 4, 5, 7])
lines = df.plot.line(title="Retail (Mem)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("Mem (KB)")
plt.savefig('/home/os/github/FP_Mining/mem/retail_time.png')

# %%
df = pd.DataFrame({'Apriori': [30.16, 27.327, 21.118, 16.37, 16.399], 'FP': [10.054, 9.56, 8.6585, 8.465, 10.77]},
                  index=[6, 7, 8, 9, 10])
lines = df.plot.line(title="Kosarak (Time)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("time (sec)")
plt.savefig('/home/os/github/FP_Mining/time/kosarak_time.png')

# %%
df = pd.DataFrame({'Apriori': [572640.0, 572632.0, 572640.0, 572620.0, 572768.0 ], 
                   'FP': [572272.0, 572300.0, 572272.0, 572192.0, 572324.0 ]},
                  index=[6, 7, 8, 9, 10])
lines = df.plot.line(title="Kosarak (Mem)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("Mem (KB)")
plt.savefig('/home/os/github/FP_Mining/mem/kosarak_time.png')

# %%
df = pd.DataFrame({'Apriori': [205.53, 70.21, 29.90, 8.91], 
                   'FP': [4.132, 3.58, 3.46, 2.66]},
                  index=[95, 96, 97, 98])
lines = df.plot.line(title="Pumsb (Time)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("time (sec)")
plt.savefig('/home/os/github/FP_Mining/time/pumsb_time.png')

# %%
df = pd.DataFrame({'Apriori': [273240.0, 273196.0, 272780.0, 272952.0], 
                   'FP': [272356.0, 272344.0, 272432.0, 272428.0]},
                  index=[95, 96, 97, 98])
lines = df.plot.line(title="Pumsb (Mem)")
lines.set_xlabel("min_sum %")
lines.set_ylabel("Mem (KB)")
plt.savefig('/home/os/github/FP_Mining/mem/pumsb_time.png')
